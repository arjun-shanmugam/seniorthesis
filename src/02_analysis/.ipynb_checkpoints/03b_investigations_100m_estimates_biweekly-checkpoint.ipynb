# %%
from differences import ATTgt
from matplotlib import pyplot as plt
plt.rcParams["figure.dpi"] = 300
plt.rcParams['savefig.dpi'] = 300
from panel_utilities import get_value_variable_names, convert_weekly_panel_to_biweekly_panel, prepare_df_for_DiD
from stats_utilities import select_controls, test_balance, add_missing_indicators
from figure_utilities import aggregate_by_event_time_and_plot, aggregate_by_time_and_plot
import pandas as pd
import joblib
from dask.distributed import Client
from dask_jobqueue import SLURMCluster



# Store paths.
INPUT_DATA = "../../data/03_cleaned/crime_analysis_weekly.parquet"
OUTPUT_FIGURES = "../../output/group_0_crimes_100m/figures"
OUTPUT_TABLES = "../../output/group_0_crimes_100m/tables"


# Read restricted sample panel dataset into memory.
df = pd.read_parquet(INPUT_DATA)

analysis='group_4_crimes_100m'

# %%
# Convert weekly panel to biweekly panel.
df = convert_weekly_panel_to_biweekly_panel(df, analysis)

# Generate value vars list and month to int dictionaries.
weekly_value_vars_crime, month_to_int_dictionary, int_to_month_dictionary  = get_value_variable_names(df, analysis)

# %%
covariates_exploration_df = select_controls(df=df, analysis=analysis, output_directory=OUTPUT_TABLES)
covariates_exploration_df
# Out:
#                                                                                              Dependent Variable  \
#
#                                                  \emph{Independent Variable}
# Panel A: Pre-treatment Outcomes                  total_twenty_seventeen_group_4_crimes_100m        0.000000e+00
#                                                  pre_treatment_change_in_group_4_crimes_100m       2.873580e-84
# Panel B: Census Tract Characteristics            frac_coll_plus2010                                1.109498e-03
#                                                  job_density_2013                                  1.923943e-23
#                                                  med_hhinc2016                                     3.540864e-05
#                                                  poor_share2010                                    2.393226e-01
#                                                  popdensity2010                                    1.769164e-01
# Panel C: Case Initiation                         for_cause                                         2.102299e-01
#                                                  no_cause                                          5.224503e-01
#                                                  non_payment                                       1.558729e-01
# Panel D: Defendant and Plaintiff Characteristics hasAttyD                                          9.934817e-01
#                                                  hasAttyP                                          2.627350e-01
#                                                  isEntityD                                         6.321416e-01
#                                                  isEntityP                                         2.948447e-02
#
#
#
#                                                  \emph{Independent Variable}
# Panel A: Pre-treatment Outcomes                  total_twenty_seventeen_group_4_crimes_100m   7.354598e-01
#                                                  pre_treatment_change_in_group_4_crimes_100m  8.670049e-01
# Panel B: Census Tract Characteristics            frac_coll_plus2010                           7.782860e-01
#                                                  job_density_2013                             5.178933e-01
#                                                  med_hhinc2016                                1.224981e-01
#                                                  poor_share2010                               5.297634e-01
#                                                  popdensity2010                               6.607443e-03
# Panel C: Case Initiation                         for_cause                                    1.764482e-08
#                                                  no_cause                                     8.995981e-01
#                                                  non_payment                                  4.059912e-07
# Panel D: Defendant and Plaintiff Characteristics hasAttyD                                     2.094824e-05
#                                                  hasAttyP                                     6.226457e-04
#                                                  isEntityD                                    1.265289e-02
#                                                  isEntityP                                    2.625077e-07

# %%
balance_table, pre_treatment_covariates = test_balance(df, analysis, covariates_exploration_df, OUTPUT_TABLES)
balance_table
# Out:
#                                                                             \
#                                                     Cases Won by Plaintiff
# Panel A total_twenty_seventeen_group_4_crimes_100m                1.665792
#         pre_treatment_change_in_group_4_crimes_100m              -0.023610
# Panel B frac_coll_plus2010                                        0.322882
#         job_density_2013                                      16069.137185
#         med_hhinc2016                                         48035.651626
# Panel D isEntityP                                                 0.808499
#
#                                                     Difference in Cases Won by Defendant  \
#                                                                               Unweighted
# Panel A total_twenty_seventeen_group_4_crimes_100m                             -0.049328
#         pre_treatment_change_in_group_4_crimes_100m                            -0.002195
# Panel B frac_coll_plus2010                                                      0.002115
#         job_density_2013                                                      926.908698
#         med_hhinc2016                                                        1312.556234
# Panel D isEntityP                                                              -0.064959
#
#                                                                    \
#                                                          \emph{p}
# Panel A total_twenty_seventeen_group_4_crimes_100m   7.354598e-01
#         pre_treatment_change_in_group_4_crimes_100m  8.670049e-01
# Panel B frac_coll_plus2010                           7.782860e-01
#         job_density_2013                             5.178933e-01
#         med_hhinc2016                                1.224981e-01
# Panel D isEntityP                                    2.625077e-07
#
#
#                                                         Weighted  \emph{p}
# Panel A total_twenty_seventeen_group_4_crimes_100m     -0.072678  0.618754
#         pre_treatment_change_in_group_4_crimes_100m     0.000067  0.995927
# Panel B frac_coll_plus2010                             -0.010201  0.114447
#         job_density_2013                             -234.255712  0.866069
#         med_hhinc2016                               -1185.570539  0.000401
# Panel D isEntityP                                      -0.048925  0.000024

# %%
# Generate indicators for missing data.

# missing_indicators = add_missing_indicators(df, ['rent_twobed2015'], pre_treatment_covariates)

# Prepare df for use with the differences package.
df = df.reset_index()
df = prepare_df_for_DiD(df=df,
                        analysis=analysis,
                        treatment_date_variable='file_week',
                        pre_treatment_covariates=pre_treatment_covariates,
                        missing_indicators=[],
                        value_vars=weekly_value_vars_crime,
                        period_to_int_dictionary=month_to_int_dictionary)

# %%
# Request computing resources.
cluster = SLURMCluster(queue='batch',
                       cores=8,
                       memory='100 GB',
                       walltime='01:00:00',
                      scheduler_options={'dashboard_address': '8787'} )
cluster.scale(jobs=1)
# Out:
# /gpfs/home/ashanmu1/seniorthesis/venv/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45544 instead
#   warnings.warn(

# %%
client = Client(cluster)

# %%
# Run DiD without conditioning on covariates.
att_gt = ATTgt(data=df, cohort_name='file_week', freq='2W', base_period='varying')
with joblib.parallel_backend("dask"):
    result = att_gt.fit(formula=analysis, control_group='never_treated', n_jobs=-1)
# Out:
# Computing ATTgt [workers=26]  100%|████████████████████| 9648/9648 [02:00<00:00,

# %%
# Plot unconditional ATT(t-g)s on a long horizon.
aggregate_by_event_time_and_plot(att_gt, OUTPUT_FIGURES, "att_gt_unconditional_event_study_long_horizon.png",
                                 start_period=-6, end_period=12,
                                 title="Unconditional Estimates of ATT(g, t), Aggregated by Month Relative to Treatment \n (Long Horizon)",
                                 treatment_month_variable='file_week', df=df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /gpfs/home/ashanmu1/seniorthesis/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /gpfs/home/ashanmu1/seniorthesis/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /gpfs/home/ashanmu1/seniorthesis/venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'file_week_alias'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Plot unconditional ATT(t-g)s on a long horizon.
# ----> 2 aggregate_by_event_time_and_plot(att_gt, OUTPUT_FIGURES, "att_gt_unconditional_event_study_long_horizon.png",
#       3                                  start_period=-6, end_period=12,
#       4                                  title="Unconditional Estimates of ATT(g, t), Aggregated by Month Relative to Treatment \n (Long Horizon)",
#       5                                  treatment_month_variable='file_week', df=df)
#
# File /gpfs/home/ashanmu1/seniorthesis/src/02_analysis/figure_utilities.py:58, in aggregate_by_event_time_and_plot(att_gt, output_folder, filename, start_period, end_period, title, treatment_month_variable, df)
#      56 # Plot sample size at each event-time.
#      57 df_copy = df.copy().reset_index()
# ---> 58 df_copy.loc[:, 'event_time'] = df_copy['month'] - df_copy[treatment_month_variable+'_alias']
#      60 cases_per_year = df_copy.groupby('event_time')['case_number'].nunique().loc[start_period:end_period]
#      61 x = cases_per_year.index
#
# File /gpfs/home/ashanmu1/seniorthesis/venv/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /gpfs/home/ashanmu1/seniorthesis/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'file_week_alias'

# %%
# Plot unconditional ATT(t)s.
aggregate_by_time_and_plot(att_gt, int_to_month_dictionary, OUTPUT_FIGURES, "att_gt_unconditional_time.png",
                           title="Unconditional Estimates of ATT(g, t), Aggregated by Month")

# %%
# Run DiD conditional on covariates.
att_gt = ATTgt(data=df, cohort_name='file_week', freq='M', base_period='varying')
formula = f'{analysis} ~ ' + '+'.join(pre_treatment_covariates)
with joblib.parallel_backend("dask"):
    result = att_gt.fit(formula=formula, control_group='never_treated', n_jobs=-1, progress_bar=True)

# %%
# Plot D.R. ATT(t-g)s on a long horizon.
aggregate_by_event_time_and_plot(att_gt, OUTPUT_FIGURES, "att_gt_dr_event_study_long_horizon.png", start_period=-3,
                                 end_period=20,
                                 title="D.R. Estimates of ATT(g, t), Aggregated by Month Relative to Treatment \n (Long Horizon)",
                                 treatment_month_variable='file_week', df=df)

# %%
# Plot D.R. ATT(t)s.
aggregate_by_time_and_plot(att_gt, int_to_month_dictionary, OUTPUT_FIGURES, "att_gt_dr_time.png",
                           title="D.R. Estimates of ATT(g, t), Aggregated by Month")
